# %%
from defogging import * # All the functions are imported from defogging.py file 
import matplotlib.pyplot as plt #importing matplotlib

# %%
image_path = r'C:\Users\mehreen\OneDrive - dgu.ac.kr\바탕 화면\Mehreens work\Denoising\maritime-defog-main\maritime-defog-main\Test_Data\V_07_01_0016.jpg'
image = np.asarray(Image.open(image_path)) / 255.0  # Convert the image values to the range [0, 1]

# input_img = np.random.rand(100, 100, 3)  # Generating a random image of shape 100x100
output_img = Defogging(image)
# output_img
# Out:
# size(input_img) :  (663, 996, 3)
# 0.00562321713495327
# size(F) :  (663, 996, 3)
# size(G) :  (663, 996, 3)
# Starting the estimate_airlight function...
# Checking Amin and Amax dimensions...
# Reducing image size...
# C:\Users\mehreen\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Removing empty clusters...
# Counting occurrences of each index...
# Defining arrays of candidate air-light values and angles...
# Estimating air-light in each pair of color channels...
# Finding most probable airlight...
# Function completed successfully!
# C:\Users\mehreen\anaconda3\Lib\site-packages\scipy\sparse\linalg\_dsolve\linsolve.py:214: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   warn('spsolve requires A be CSC or CSR matrix format',

# %%
import cv2
cv2.imshow('Defogged Image', image)
cv2.waitKey(0)  # Wait until a key is pressed
cv2.destroyAllWindows()  # Destroy all OpenCV windows

# %%
# find frequency of pixels in range 0-255 
img = np.asarray(Image.open(image_path))
histr = cv2.calcHist([img],[0],None,[256],[0,256]) 
  
# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
# find frequency of pixels in range 0-255 
img = np.asarray(Image.open(image_path))
histr = cv2.calcHist([img],[0],None,[256],[0,256]) 
  
# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
output_img.max(), output_img.min()
# Out:
# (0.02740654492100408, 0.0)

# %%
output_img_normal = output_img*255/output_img.max()
output_img_normal = (output_img_normal).round(0).astype(np.uint8)

# %%
# find frequency of pixels in range 0-255 
# img = np.asarray(Image.open(image_path))
histr = cv2.calcHist([output_img_normal],[0],None,[256],[0,256]) 
  
# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
type(img), type(output_img_normal)
# Out:
# (numpy.ndarray, numpy.ndarray)
